# %%
import pickle

# %%
loaded_model=pickle.load(open('classification.sav', 'rb'))

# %%
Future_Prediction=loaded_model.predict([[10, 20, 0, 1]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[0]
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearSVC was fitted with feature names
#   warnings.warn(
