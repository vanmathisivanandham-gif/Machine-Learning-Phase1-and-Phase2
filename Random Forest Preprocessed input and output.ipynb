# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre - insurance_pre.csv")
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
scy=StandardScaler()
y_train=scy.fit_transform(y_train)
y_test=scy.transform(y_test)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(criterion='squared_error',max_features='sqrt')
regressor.fit(x_train, y_train)
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_features='sqrt')

# %%
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.8679900477128711

# %%
import pickle
filename='preprocessinginputoutput.sav'

# %%
pickle.dump(regressor, open(filename, 'wb'))

# %%
preinput=sc.transform([[100, 800, 0, 1, 0]])
preinput
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[  4.32192006, 123.43005305,  -0.89833872,   1.02378711,
#          -0.50466988]])

# %%
loaded_model=pickle.load(open('preprocessing.sav', 'rb'))
result=loaded_model.predict(preinput)
result
# Out:
# array([12764.425712])

# %%
preoutput=scy.inverse_transform([result])
preoutput
# Out:
# array([[1.51574991e+08]])

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 11
# BMI: 22
# Children: 5
# Sex Male 0 or 1: male
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 4
#       2 bmi_input=float(input("BMI:"))
#       3 children_input=float(input("Children:"))
# ----> 4 sex_male_input=int(input("Sex Male 0 or 1:"))
#       5 smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
#
# ValueError: invalid literal for int() with base 10: 'male'
