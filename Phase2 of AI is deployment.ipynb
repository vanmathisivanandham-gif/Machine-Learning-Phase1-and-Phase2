# %%
#importing pickle library
import pickle

# %%
#loading the file model by reading it
loaded_model=pickle.load(open("final_model_slr.sav", 'rb'))
num=int(input("Enter years of experience"))
result=loaded_model.predict([[num]])
# Out:
# Enter years of experience 0
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])

# %%
#for freshers the num value should be zero and when running, it gives the bias value of 26777, which is the origin value or starting point of the slope
#model's bias/origin value is 26777 which means y=wx+b is y=9360(input value/0)*26777
